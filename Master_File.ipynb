# %%
#Importing the dependecies
#!conda install --yes basemap 

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib import colors
# %matplotlib inline
from mpl_toolkits.basemap import Basemap
import matplotlib.lines as mlines
from matplotlib.legend_handler import HandlerLine2D
import seaborn as sns
import matplotlib
matplotlib.rcParams.update({'font.size': 18})

# %%
# Loading the file
file1 = "impacts.csv"
file2 = "meteorite-landings.csv"

# %% [markdown]
# # Asteroids Data

# %%
# Reading the asteroids csv data file 
impacts = pd.read_csv(file1)

# Displaying the data table for preview
impacts.head()
# Out:
#   Object Name  Period Start  Period End  Possible Impacts  \
# 0    2006 WP1          2017        2017                 1
# 1     2013 YB          2017        2046                23
# 2     2008 US          2017        2062                30
# 3  2010 VR139          2017        2076                24
# 4  2015 ME131          2017        2096                85
#
#    Cumulative Impact Probability  Asteroid Velocity  Asteroid Magnitude  \
# 0                   5.200000e-09              17.77                28.3
# 1                   7.600000e-05               8.98                31.4
# 2                   1.600000e-05              18.33                31.4
# 3                   2.000000e-07               4.99                26.7
# 4                   2.300000e-08              19.46                19.2
#
#    Asteroid Diameter (km)  Cumulative Palermo Scale  Maximum Palermo Scale  \
# 0                   0.007                     -8.31                  -8.31
# 1                   0.002                     -6.60                  -6.96
# 2                   0.002                     -6.48                  -6.87
# 3                   0.016                     -6.83                  -6.95
# 4                   0.497                     -3.85                  -4.30
#
#   Maximum Torino Scale
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
asteroids = impacts.rename(columns ={"Object Name": "Name"})
asteroids.head()
# Out:
#          Name  Period Start  Period End  Possible Impacts  \
# 0    2006 WP1          2017        2017                 1
# 1     2013 YB          2017        2046                23
# 2     2008 US          2017        2062                30
# 3  2010 VR139          2017        2076                24
# 4  2015 ME131          2017        2096                85
#
#    Cumulative Impact Probability  Asteroid Velocity  Asteroid Magnitude  \
# 0                   5.200000e-09              17.77                28.3
# 1                   7.600000e-05               8.98                31.4
# 2                   1.600000e-05              18.33                31.4
# 3                   2.000000e-07               4.99                26.7
# 4                   2.300000e-08              19.46                19.2
#
#    Asteroid Diameter (km)  Cumulative Palermo Scale  Maximum Palermo Scale  \
# 0                   0.007                     -8.31                  -8.31
# 1                   0.002                     -6.60                  -6.96
# 2                   0.002                     -6.48                  -6.87
# 3                   0.016                     -6.83                  -6.95
# 4                   0.497                     -3.85                  -4.30
#
#   Maximum Torino Scale
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
asteroids.loc[asteroids['Maximum Palermo Scale'].idxmax()]
# Out:
# Name                             29075 (1950 DA)
# Period Start                                2880
# Period End                                  2880
# Possible Impacts                               1
# Cumulative Impact Probability            0.00012
# Asteroid Velocity                           14.1
# Asteroid Magnitude                          17.6
# Asteroid Diameter (km)                       1.3
# Cumulative Palermo Scale                   -1.42
# Maximum Palermo Scale                      -1.42
# Maximum Torino Scale                         (*)
# Name: 682, dtype: object

# %%
def impact_score(impact):
    if impact < -8:
        return 'darkmagenta'
    elif impact < -4:
        return 'LightBlue'
    else:
        return 'red'
    
def asteroid_scale(scale):
    return (scale) * -100;
  

x = asteroids['Possible Impacts']
y = asteroids['Period Start']
z = asteroids['Maximum Palermo Scale']

asteroids_list = asteroids['Maximum Palermo Scale']
asteroids_list_colors = [impact_score(impact) for impact in asteroids_list]

asteroids_scale_list= [asteroid_scale(scale) for scale in asteroids_list]

fig = plt.figure(figsize=(10,8))
plt.ylim(2016,2030)
plt.xlim(-10,100)
plt.scatter(x, y, s=asteroids_scale_list , c=asteroids_list_colors, alpha=0.6, marker="o", edgecolors="black")

plt.title("Possible Future Impacts")
plt.xlabel("Possible Impacts")
plt.ylabel("Years")
plt.grid(True)

plt.savefig("../possible_impacts_asteroids.png")
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.scatter(asteroids["Possible Impacts"]/(asteroids['Period End'] - asteroids['Period Start']), 
           asteroids["Asteroid Velocity"],s=asteroids["Asteroid Diameter (km)"]*1000, alpha=0.5)
ax.set_xscale('log')
ax.set_xlim([1e-2,20])
ax.set_xlabel('Number of possible impacts per year')
ax.set_ylabel('Asteroid speed (km/s)')
plt.title("Impacts by Speed")
plt.grid(True)
sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, 
        color_codes=False, rc=None)
plt.savefig("../possible_impacts_asteroids.png")

# %%
fig = plt.figure(figsize=(10,8))
 # ax = fig.add_subplot(111)# ax = fi 
x = np.log10(asteroids['Asteroid Diameter (km)']*1000)
y = asteroids['Asteroid Velocity']
_ = plt.hist2d(x,y, bins=30, figure=fig, cmap=plt.cm.cubehelix)
plt.colorbar()
plt.title("Speed by Diameter")
plt.xlabel('Asteroid Diameter (m)')
plt.ylabel('Asteroid Velocity (km/s)')
# Out:
# Text(0,0.5,'Asteroid Velocity (km/s)')

# %%
fig = plt.figure(figsize=(10,8))
# ax = fig.add_subplot(111)
x = np.log10(asteroids['Cumulative Impact Probability'])
y = asteroids['Cumulative Palermo Scale']
_ = plt.hist2d(x,y, bins=50, figure=fig, cmap=plt.cm.cubehelix)
plt.colorbar()
plt.xlabel('Cumulative Impact Probability')
plt.ylabel('Cumulative Palermo Scale')
# Out:
# Text(0,0.5,'Cumulative Palermo Scale')

# %% [markdown]
# ## Meteorites Data

# %%
# Reading the meteor csv data file 
meteor = pd.read_csv(file2)
meteor.head()
# Out:
#        name   id nametype     recclass      mass  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong               GeoLocation
# 0    6.08333     (50.775000, 6.083330)
# 1   10.23333    (56.183330, 10.233330)
# 2 -113.00000  (54.216670, -113.000000)
# 3  -99.90000   (16.883330, -99.900000)
# 4  -64.95000  (-33.166670, -64.950000)

# %%
meteor = meteor.rename(columns ={"recclass": "type",
                                 "fall": "discovery",
                                 "nametype": "appearance",
                                 "reclat": "lat",
                                 "reclong": "long",
                                 "GeoLocation": "coordinates"})
meteor.head()
# Out:
#        name   id appearance         type      mass discovery    year  \
# 0    Aachen    1      Valid           L5      21.0      Fell  1880.0
# 1    Aarhus    2      Valid           H6     720.0      Fell  1951.0
# 2      Abee    6      Valid          EH4  107000.0      Fell  1952.0
# 3  Acapulco   10      Valid  Acapulcoite    1914.0      Fell  1976.0
# 4   Achiras  370      Valid           L6     780.0      Fell  1902.0
#
#         lat       long               coordinates
# 0  50.77500    6.08333     (50.775000, 6.083330)
# 1  56.18333   10.23333    (56.183330, 10.233330)
# 2  54.21667 -113.00000  (54.216670, -113.000000)
# 3  16.88333  -99.90000   (16.883330, -99.900000)
# 4 -33.16667  -64.95000  (-33.166670, -64.950000)

# %%
#Dropping some unecessary columns 
meteor = meteor.drop(columns = ["id", "coordinates"])
meteor.head()
# Out:
#        name appearance         type      mass discovery    year       lat  \
# 0    Aachen      Valid           L5      21.0      Fell  1880.0  50.77500
# 1    Aarhus      Valid           H6     720.0      Fell  1951.0  56.18333
# 2      Abee      Valid          EH4  107000.0      Fell  1952.0  54.21667
# 3  Acapulco      Valid  Acapulcoite    1914.0      Fell  1976.0  16.88333
# 4   Achiras      Valid           L6     780.0      Fell  1902.0 -33.16667
#
#         long
# 0    6.08333
# 1   10.23333
# 2 -113.00000
# 3  -99.90000
# 4  -64.95000

# %%
# To sort from highest to lowest, ascending=False must be passed in
meteor_df = meteor.sort_values("year", ascending=False)
meteor_df
# Out:
#                         name appearance                   type       mass  \
# 38188                     Ur      Valid                   Iron        NaN
# 30679  Northwest Africa 7701      Valid                    CK6      55.00
# 30760  Northwest Africa 7822      Valid         Achondrite-ung      45.80
# 30773  Northwest Africa 7857      Valid                    LL6     246.00
# 30759  Northwest Africa 7812      Valid                Angrite      46.20
# 194              Chelyabinsk      Valid                    LL5  100000.00
# 30772  Northwest Africa 7856      Valid                    LL6     517.00
# 30771  Northwest Africa 7855      Valid                     H4     916.00
# 30774  Northwest Africa 7858      Valid                     H4     459.00
# 30776  Northwest Africa 7861      Valid                     L5     611.00
# 30777  Northwest Africa 7862      Valid                   L4/5     317.00
# 30778  Northwest Africa 7863      Valid                    LL5    1000.00
# 30727  Northwest Africa 7755      Valid  Martian (shergottite)      30.00
# 30689  Northwest Africa 7712      Valid                   R3-6      53.00
# 30690  Northwest Africa 7713      Valid                     H5    1255.00
# 30691  Northwest Africa 7714      Valid              Howardite     119.00
# 30692  Northwest Africa 7717      Valid                     H4      85.00
# 30694  Northwest Africa 7720      Valid                     H4    2500.00
# 30695  Northwest Africa 7721      Valid  Martian (shergottite)      32.00
# 30696  Northwest Africa 7722      Valid                     L6     155.00
# 30697  Northwest Africa 7724      Valid                     L6    1000.00
# 30703  Northwest Africa 7733      Valid                  LL5-6    1835.00
# 30698  Northwest Africa 7729      Valid                    LL5     250.00
# 30700  Northwest Africa 7730      Valid                  LL3.4     373.00
# 30701  Northwest Africa 7731      Valid                  L3.00      81.00
# 30702  Northwest Africa 7732      Valid                     H6     550.00
# 30687  Northwest Africa 7710      Valid                    LL5     211.00
# 30704  Northwest Africa 7734      Valid                  LL4-6    1900.00
# 30705  Northwest Africa 7735      Valid                     L4     210.00
# 30706  Northwest Africa 7736      Valid                    LL6     490.00
# ...                      ...        ...                    ...        ...
# 29558  Northwest Africa 5828      Valid                     H5    2799.00
# 29568  Northwest Africa 5838      Valid                     H6    1438.70
# 29574  Northwest Africa 5844      Valid                     L5    1000.00
# 29575  Northwest Africa 5845      Valid                     L5    3000.00
# 29582  Northwest Africa 5852      Valid                     L6     293.00
# 29583  Northwest Africa 5853      Valid                     L6      74.50
# 29926  Northwest Africa 6514      Valid               LL(L)3.1    3200.00
# 30060  Northwest Africa 6704      Valid         Achondrite-ung    8387.00
# 30107  Northwest Africa 6853      Valid                    L~6      22.28
# 30346   Northwest Africa 724      Valid                    LL3    1200.00
# 30353   Northwest Africa 725      Valid            Acapulcoite    3824.00
# 30364   Northwest Africa 726      Valid                     H4     354.00
# 30911               Nova 008      Valid                     L6    4200.00
# 30912               Nova 009      Valid                     H4    7300.00
# 30919     Nuevo Mercurio (c)      Valid                   H5-6      16.80
# 31018         Österplana 006     Relict              Relict OC        NaN
# 35808   Ramlat as Sahmah 426      Valid                     H4      92.00
# 35809   Ramlat as Sahmah 427      Valid                     H5       7.60
# 35810   Ramlat as Sahmah 428      Valid                     L6   16247.00
# 36029              Rio Bunge      Valid                      L      11.00
# 36030         Río Cuarto 001      Valid                Eucrite      62.70
# 37375    Sayh al Uhaymir 557      Valid                     H4       3.00
# 37641       Sleeper Camp 005      Valid                     H5     129.00
# 37704            Squaw Creek      Valid             Iron, IIAB   14500.00
# 38118                 Uasara      Valid             Iron, IIAB    3140.00
# 38128               Um-Hadid      Valid           Mesosiderite   15400.00
# 38201               Valencia      Valid                     H5   33500.00
# 38224           Villa Regina      Valid            Iron, IIIAB    5030.00
# 38328              Wiltshire      Valid                     H5   92750.00
# 45700               Zaragoza      Valid           Iron, IVA-an  162000.00
#
#       discovery    year       lat       long
# 38188     Found  2501.0  30.90000   46.01667
# 30679     Found  2101.0   0.00000    0.00000
# 30760     Found  2013.0   0.00000    0.00000
# 30773     Found  2013.0   0.00000    0.00000
# 30759     Found  2013.0   0.00000    0.00000
# 194        Fell  2013.0  54.81667   61.11667
# 30772     Found  2013.0   0.00000    0.00000
# 30771     Found  2013.0   0.00000    0.00000
# 30774     Found  2013.0   0.00000    0.00000
# 30776     Found  2013.0   0.00000    0.00000
# 30777     Found  2013.0   0.00000    0.00000
# 30778     Found  2013.0   0.00000    0.00000
# 30727     Found  2013.0   0.00000    0.00000
# 30689     Found  2012.0   0.00000    0.00000
# 30690     Found  2012.0   0.00000    0.00000
# 30691     Found  2012.0   0.00000    0.00000
# 30692     Found  2012.0   0.00000    0.00000
# 30694     Found  2012.0   0.00000    0.00000
# 30695     Found  2012.0   0.00000    0.00000
# 30696     Found  2012.0   0.00000    0.00000
# 30697     Found  2012.0   0.00000    0.00000
# 30703     Found  2012.0   0.00000    0.00000
# 30698     Found  2012.0   0.00000    0.00000
# 30700     Found  2012.0   0.00000    0.00000
# 30701     Found  2012.0   0.00000    0.00000
# 30702     Found  2012.0   0.00000    0.00000
# 30687     Found  2012.0   0.00000    0.00000
# 30704     Found  2012.0   0.00000    0.00000
# 30705     Found  2012.0   0.00000    0.00000
# 30706     Found  2012.0   0.00000    0.00000
# ...         ...     ...       ...        ...
# 29558     Found     NaN   0.00000    0.00000
# 29568     Found     NaN   0.00000    0.00000
# 29574     Found     NaN   0.00000    0.00000
# 29575     Found     NaN   0.00000    0.00000
# 29582     Found     NaN   0.00000    0.00000
# 29583     Found     NaN   0.00000    0.00000
# 29926     Found     NaN   0.00000    0.00000
# 30060     Found     NaN   0.00000    0.00000
# 30107     Found     NaN   0.00000    0.00000
# 30346     Found     NaN  30.23333   -5.86667
# 30353     Found     NaN  30.60000   -5.05000
# 30364     Found     NaN  31.03333   -4.00000
# 30911     Found     NaN       NaN        NaN
# 30912     Found     NaN       NaN        NaN
# 30919     Found     NaN  24.26000 -102.14083
# 31018     Found     NaN  58.58333   13.43333
# 35808     Found     NaN  20.11306   56.39750
# 35809     Found     NaN  20.09889   56.40972
# 35810     Found     NaN  20.10361   56.32694
# 36029     Found     NaN       NaN        NaN
# 36030     Found     NaN -32.87167  -64.22333
# 37375     Found     NaN  20.17417   56.51111
# 37641     Found     NaN -30.17367  126.29233
# 37704     Found     NaN  32.00000  -98.00000
# 38118     Found     NaN   0.00000    0.00000
# 38128     Found     NaN  21.69500   50.59667
# 38201     Found     NaN  39.00000   -0.03333
# 38224     Found     NaN -39.10000  -67.06667
# 38328     Found     NaN  51.14967   -1.81000
# 45700     Found     NaN  41.65000   -0.86667
#
# [45716 rows x 8 columns]

# %%
meteor_count = meteor["year"].value_counts()
meteor_count.head()
# Out:
# 2003.0    3323
# 1979.0    3046
# 1998.0    2697
# 2006.0    2456
# 1988.0    2296
# Name: year, dtype: int64

# %%
# Remove the rows with missing data
clean_meteor_df = meteor.dropna(how="any")
clean_meteor_df.count()
# Out:
# name          38116
# appearance    38116
# type          38116
# mass          38116
# discovery     38116
# year          38116
# lat           38116
# long          38116
# dtype: int64

# %%
clean_meteor_df.head()
# Out:
#        name appearance         type      mass discovery    year       lat  \
# 0    Aachen      Valid           L5      21.0      Fell  1880.0  50.77500
# 1    Aarhus      Valid           H6     720.0      Fell  1951.0  56.18333
# 2      Abee      Valid          EH4  107000.0      Fell  1952.0  54.21667
# 3  Acapulco      Valid  Acapulcoite    1914.0      Fell  1976.0  16.88333
# 4   Achiras      Valid           L6     780.0      Fell  1902.0 -33.16667
#
#         long
# 0    6.08333
# 1   10.23333
# 2 -113.00000
# 3  -99.90000
# 4  -64.95000

# %%
def get_discovery_color(discovery):
    if discovery == 'Fell':
        return 'Green'
    elif discovery == 'Found':
        return 'Red'
    else:
        return 'Gold'

lat = clean_meteor_df['lat'].values
lon = clean_meteor_df['long'].values
mass = clean_meteor_df['mass'].values

discovery_type_list = clean_meteor_df['discovery']
discovery_color_list = [get_discovery_color(discovery_type) for discovery_type in discovery_type_list]

fig = plt.figure(figsize=(16,11))
m = Basemap()
m.shadedrelief()

m.scatter(lon, lat, latlon=True,
          c=discovery_color_list, s=mass/20000,
          alpha=0.5, marker="o", edgecolors="black")

plt.title("Meteorites Impacts by Mass")
plt.savefig("../meteorites_impact_by_mass.png")

# %%
# 
fig = plt.figure(figsize=(16,11))
m = Basemap()
m.bluemarble(alpha=0.8)
m.drawcoastlines(color="#555566", linewidth=1)
plt.scatter(meteor['long'], meteor['lat'], c='red', marker='.', alpha=0.5)
plt.title("Full Disk Orthographic Projection")
# Out:
# Text(0.5,1,'Full Disk Orthographic Projection')
